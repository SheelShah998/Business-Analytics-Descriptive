# %% [markdown]
# ### Recommendation Example: Small Dataset

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd

# %% [markdown]
# ### Loading the Dataset

# %%
# uploading in colab
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-62488b71-8384-4ebe-b396-4bab71fb25da" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-62488b71-8384-4ebe-b396-4bab71fb25da">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving example_data.xlsx to example_data.xlsx

# %%
# Reading the dataset
ratings = pd.read_excel('example_data.xlsx', index_col = 0)

# %%
# top few rows
ratings.head()
# Out:
#         TopGun  Terminator  Dune  LittleWomen  ForestGump  Titanic
# Jack       5.0         4.0   4.0          NaN         1.0      1.0
# Joan       4.0         3.0   5.0          2.0         2.0      NaN
# Sarah      1.0         NaN   NaN          4.0         3.0      5.0
# Alex       NaN         2.0   1.0          4.0         NaN      5.0
# Hannah     1.0         NaN   2.0          3.0         3.0      4.0

# %% [markdown]
# ### Item Based Collaborative Filtering

# %%
# Correlation matrix
corrMatrix = ratings.corr()
corrMatrix.head(6)
# Out:
#                TopGun  Terminator      Dune  LittleWomen  ForestGump   Titanic
# TopGun       1.000000    1.000000  0.838628    -0.866025   -0.971061 -0.970725
# Terminator   1.000000    1.000000  0.720577    -1.000000   -1.000000 -1.000000
# Dune         0.838628    0.720577  1.000000    -0.960769   -0.654654 -0.995871
# LittleWomen -0.866025   -1.000000 -0.960769     1.000000    0.866025  1.000000
# ForestGump  -0.971061   -1.000000 -0.654654     0.866025    1.000000  0.970725
# Titanic     -0.970725   -1.000000 -0.995871     1.000000    0.970725  1.000000

# %%
# Correlation matrix
corrMatrix = ratings.corr()
corrMatrix.head(5)
# Out:
#                TopGun  Terminator      Dune  LittleWomen  ForestGump   Titanic
# TopGun       1.000000    1.000000  0.838628    -0.866025   -0.971061 -0.970725
# Terminator   1.000000    1.000000  0.720577    -1.000000   -1.000000 -1.000000
# Dune         0.838628    0.720577  1.000000    -0.960769   -0.654654 -0.995871
# LittleWomen -0.866025   -1.000000 -0.960769     1.000000    0.866025  1.000000
# ForestGump  -0.971061   -1.000000 -0.654654     0.866025    1.000000  0.970725

# %%
# Correlation matrix
corrMatrix = ratings.corr()
corrMatrix.head(4)
# Out:
#                TopGun  Terminator      Dune  LittleWomen  ForestGump   Titanic
# TopGun       1.000000    1.000000  0.838628    -0.866025   -0.971061 -0.970725
# Terminator   1.000000    1.000000  0.720577    -1.000000   -1.000000 -1.000000
# Dune         0.838628    0.720577  1.000000    -0.960769   -0.654654 -0.995871
# LittleWomen -0.866025   -1.000000 -0.960769     1.000000    0.866025  1.000000

# %%
# Correlation matrix
corrMatrix = ratings.corr()
corrMatrix.head(3)
# Out:
#               TopGun  Terminator      Dune  LittleWomen  ForestGump   Titanic
# TopGun      1.000000    1.000000  0.838628    -0.866025   -0.971061 -0.970725
# Terminator  1.000000    1.000000  0.720577    -1.000000   -1.000000 -1.000000
# Dune        0.838628    0.720577  1.000000    -0.960769   -0.654654 -0.995871

# %%
# Correlation matrix
corrMatrix = ratings.corr()
corrMatrix.head(2)
# Out:
#             TopGun  Terminator      Dune  LittleWomen  ForestGump   Titanic
# TopGun         1.0         1.0  0.838628    -0.866025   -0.971061 -0.970725
# Terminator     1.0         1.0  0.720577    -1.000000   -1.000000 -1.000000

# %%
# Correlation matrix
corrMatrix = ratings.corr()
corrMatrix.head(1)
# Out:
#         TopGun  Terminator      Dune  LittleWomen  ForestGump   Titanic
# TopGun     1.0         1.0  0.838628    -0.866025   -0.971061 -0.970725

# %%
# Find similar item
corrMatrix['Titanic'].sort_values(ascending = False)
# Out:
# LittleWomen    1.000000
# Titanic        1.000000
# ForestGump     0.970725
# TopGun        -0.970725
# Dune          -0.995871
# Terminator    -1.000000
# Name: Titanic, dtype: float64

# %%
# Find similar item
corrMatrix['ForestGump'].sort_values(ascending = False)
# Out:
# ForestGump     1.000000
# Titanic        0.970725
# LittleWomen    0.866025
# Dune          -0.654654
# TopGun        -0.971061
# Terminator    -1.000000
# Name: ForestGump, dtype: float64

# %%
# Find similar item
corrMatrix['Dune'].sort_values(ascending = False)
# Out:
# Dune           1.000000
# TopGun         0.838628
# Terminator     0.720577
# ForestGump    -0.654654
# LittleWomen   -0.960769
# Titanic       -0.995871
# Name: Dune, dtype: float64

# %%
# Find similar item
corrMatrix['LittleWomen'].sort_values(ascending = False)
# Out:
# Titanic        1.000000
# LittleWomen    1.000000
# ForestGump     0.866025
# TopGun        -0.866025
# Dune          -0.960769
# Terminator    -1.000000
# Name: LittleWomen, dtype: float64

# %%
# Find similar item
corrMatrix['TopGun'].sort_values(ascending = False)
# Out:
# TopGun         1.000000
# Terminator     1.000000
# Dune           0.838628
# LittleWomen   -0.866025
# Titanic       -0.970725
# ForestGump    -0.971061
# Name: TopGun, dtype: float64

# %%
# Find similar item
corrMatrix['Terminator'].sort_values(ascending = False)
# Out:
# TopGun         1.000000
# Terminator     1.000000
# Dune           0.720577
# LittleWomen   -1.000000
# ForestGump    -1.000000
# Titanic       -1.000000
# Name: Terminator, dtype: float64

# %% [markdown]
# ### User Based Collaborative Filtering

# %%
# Rating Transposing
ratings.T
# Out:
#              Jack  Joan  Sarah  Alex  Hannah
# TopGun        5.0   4.0    1.0   NaN     1.0
# Terminator    4.0   3.0    NaN   2.0     NaN
# Dune          4.0   5.0    NaN   1.0     2.0
# LittleWomen   NaN   2.0    4.0   4.0     3.0
# ForestGump    1.0   2.0    3.0   NaN     3.0
# Titanic       1.0   NaN    5.0   5.0     4.0

# %%
# Correlation Matrix
corrMatrix = ratings.T.corr()
corrMatrix.head()
# Out:
#             Jack      Joan     Sarah      Alex    Hannah
# Jack    1.000000  0.745356 -0.866025 -0.970725 -0.939336
# Joan    0.745356  1.000000 -0.944911 -0.928571 -0.754337
# Sarah  -0.866025 -0.944911  1.000000  1.000000  0.969458
# Alex   -0.970725 -0.928571  1.000000  1.000000  0.960769
# Hannah -0.939336 -0.754337  0.969458  0.960769  1.000000

# %%
# Find similar user 
corrMatrix['Sarah'].sort_values(ascending = False)
# Out:
# Sarah     1.000000
# Alex      1.000000
# Hannah    0.969458
# Jack     -0.866025
# Joan     -0.944911
# Name: Sarah, dtype: float64

# %%
# Find similar user 
corrMatrix['Alex'].sort_values(ascending = False)
# Out:
# Sarah     1.000000
# Alex      1.000000
# Hannah    0.960769
# Joan     -0.928571
# Jack     -0.970725
# Name: Alex, dtype: float64

# %%
# Find similar user 
corrMatrix['Hannah'].sort_values(ascending = False)
# Out:
# Hannah    1.000000
# Sarah     0.969458
# Alex      0.960769
# Joan     -0.754337
# Jack     -0.939336
# Name: Hannah, dtype: float64

# %%
# Find similar user 
corrMatrix['Jack'].sort_values(ascending = False)
# Out:
# Jack      1.000000
# Joan      0.745356
# Sarah    -0.866025
# Hannah   -0.939336
# Alex     -0.970725
# Name: Jack, dtype: float64

# %%
# Find similar user 
corrMatrix['Joan'].sort_values(ascending = False)
# Out:
# Joan      1.000000
# Jack      0.745356
# Hannah   -0.754337
# Alex     -0.928571
# Sarah    -0.944911
# Name: Joan, dtype: float64
